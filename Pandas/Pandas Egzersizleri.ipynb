# %%
import pandas as pd

# %%
pd.DataFrame({'Yes': [30, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   30  131
# 1   21    2

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([20,15,37],index=['2015 Sales', '2016 Sales', '2017 Sales'],name='Product B')
# Out:
# 2015 Sales    20
# 2016 Sales    15
# 2017 Sales    37
# Name: Product B, dtype: int64

# %%
pd.Series([20,15,37],name='Product B')
# Out:
# 0    20
# 1    15
# 2    37
# Name: Product B, dtype: int64

# %%
df = pd.read_csv('winemag-data-130k-v2.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df.shape
# Out:
# (129971, 14)

# %%
df_wine=pd.read_csv('winemag-data-130k-v2.csv',index_col=0)

# %%
df_wine.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
df_wine.country
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
df_wine.price
# Out:
# 0          NaN
# 1         15.0
# 2         14.0
# 3         13.0
# 4         65.0
#           ...
# 129966    28.0
# 129967    75.0
# 129968    30.0
# 129969    32.0
# 129970    21.0
# Name: price, Length: 129971, dtype: float64

# %%
df_wine.iloc[300]
# Out:
# country                                                                 US
# description              Soft, light in body and easy to drink, this Sa...
# designation                                                         Estate
# points                                                                  87
# price                                                                   28
# province                                                        California
# region_1                                                       Napa Valley
# region_2                                                              Napa
# taster_name                                                            NaN
# taster_twitter_handle                                                  NaN
# title                       Benessere 2007 Estate Sangiovese (Napa Valley)
# variety                                                         Sangiovese
# ...

# %%
df_wine.iloc[:,0]
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
df_wine.iloc[:3,1]
# Out:
# 0    Aromas include tropical fruit, broom, brimston...
# 1    This is ripe and fruity, a wine that is smooth...
# 2    Tart and snappy, the flavors of lime flesh and...
# Name: description, dtype: object

# %%
df_wine.iloc[[0,1,2],1]
# Out:
# 0    Aromas include tropical fruit, broom, brimston...
# 1    This is ripe and fruity, a wine that is smooth...
# 2    Tart and snappy, the flavors of lime flesh and...
# Name: description, dtype: object

# %%
df_wine.iloc[-7:,4]
# Out:
# 129964     NaN
# 129965    28.0
# 129966    28.0
# 129967    75.0
# 129968    30.0
# 129969    32.0
# 129970    21.0
# Name: price, dtype: float64

# %%
df_wine.loc[5,'country']
# Out:
# 'Spain'

# %%
df_wine.loc[:5,['taster_name', 'taster_twitter_handle']]
# Out:
#           taster_name taster_twitter_handle
# 0       Kerin O’Keefe          @kerinokeefe
# 1          Roger Voss            @vossroger
# 2        Paul Gregutt           @paulgwine
# 3  Alexander Peartree                   NaN
# 4        Paul Gregutt           @paulgwine
# 5   Michael Schachner           @wineschach

# %%
df_wine.set_index("title")
# Out:
#                                                      country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)             US
# St. Julian 2013 Reserve Late Harvest Riesling (...        US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...        US
# ...                                                      ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...   Germany
# Citation 2004 Pinot Noir (Oregon)                         US
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)    France
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)         France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...    France
#
#                                                                                           description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Aromas include tropical fruit, broom, brimston...
# ...

# %%
df_wine.country == 'US'
# Out:
# 0         False
# 1         False
# 2          True
# 3          True
# 4          True
#           ...
# 129966    False
# 129967     True
# 129968    False
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
df_wine.loc[df_wine.country == 'US']
# Out:
#        country                                        description  \
# 2           US  Tart and snappy, the flavors of lime flesh and...
# 3           US  Pineapple rind, lemon pith and orange blossom ...
# 4           US  Much like the regular bottling from 2012, this...
# 10          US  Soft, supple plum envelopes an oaky structure ...
# 12          US  Slightly reduced, this wine offers a chalky, t...
# ...        ...                                                ...
# 129945      US  Hailing from one of the more popular vineyards...
# 129949      US  There's no bones about the use of oak in this ...
# 129950      US  This opens with herbaceous dollops of thyme an...
# 129952      US  This Zinfandel from the eastern section of Nap...
# 129967      US  Citation is given as much as a decade of bottl...
#
#                                designation  points  price    province  \
# 2                                      NaN      87   14.0      Oregon
# ...

# %%
df_wine.loc[(df_wine.country == 'US')& (df_wine.points <= 80)]
# Out:
#        country                                        description  \
# 7333        US  Too sweet by far for a table wine, with simple...
# 7334        US  Excessively ripe fruit verging on baked, burnt...
# 13025       US  Just barely acceptable, this soft, semisweet C...
# 14337       US  Sweet and sour, with cherry and raspberry jam ...
# 14338       US  Light, almost ephemeral, this pale Pinot does ...
# ...        ...                                                ...
# 128257      US  Simple but refreshing and crisp, with nice gra...
# 128258      US  This Chardonnay-Viognier blend is slightly swe...
# 128259      US  While there's some nice, honest fruit here, it...
# 128260      US  Banana, clove and orange peel open for this sw...
# 128261      US  Short and slightly sweet, there's nutty overto...
#
#                  designation  points  price      province  \
# 7333                     NaN      80   10.0    California
# ...

# %%
df_wine.loc[df_wine.country.isin(['France','Italy'])]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# 7       France  This dry and restrained wine offers spice in p...
# 9       France  This has great depth of flavor with its fresh ...
# 11      France  This is a dry wine, very spicy, with a tight, ...
# ...        ...                                                ...
# 129964  France  Initially quite muted, this wine slowly develo...
# 129965  France  While it's rich, this beautiful dry wine also ...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %%
df_wine.loc[df_wine.price.notnull()]
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# 5          Spain  Blackberry and raspberry aromas show a typical...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price        province  \
# ...

# %%
df_wine.loc[df_wine.region_1.notnull()]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 2           US  Tart and snappy, the flavors of lime flesh and...
# 3           US  Pineapple rind, lemon pith and orange blossom ...
# 4           US  Much like the regular bottling from 2012, this...
# 5        Spain  Blackberry and raspberry aromas show a typical...
# ...        ...                                                ...
# 129965  France  While it's rich, this beautiful dry wine also ...
# 129967      US  Citation is given as much as a decade of bottl...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price           province  \
# 0                             Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...
